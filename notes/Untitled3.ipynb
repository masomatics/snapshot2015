# %%
import numpy as np
import scipy as sp
from matplotlib import pyplot as plt
# %matplotlib inline
import sys
sys.path.append("../source") 
import Discrete_Doucet_system as dd
reload(dd)
# Out:
# <module 'Discrete_Doucet_system' from '../source/Discrete_Doucet_system.pyc'>

# %%
theta_approx40 = np.array([ -1.23481912 ,  0.2656946,    3.44532589, -13.88883684,   0.2       ])
theta_approx12 = np.array( [-0.6987144,   -0.49409199, -25.09107122 ,  6.33720366,   0.2       ]    )
#theta_approx12 = np.array( [ 0,  -0.5, -25 ,  6,   0.2       ])

theta_approx15 = np.array([ 0.01680314,  0.92671352,  3.81007087,  0.21282745 , 0.2       ])
theta_approx4 = np.array([  1.49326723,   0.27913057 , -9.27602837 ,-12.36208391,   0.2       ])

#theta_approx12 = np.array([ 0.01680314,  0.92671352,  3.81007087,  0.21282745 , 0.2       ])
dsystem = dd.Discrete_Doucet_system()
dsystem40 = dd.Discrete_Doucet_system(theta =theta_approx40 )
dsystem12= dd.Discrete_Doucet_system(theta = theta_approx12 )
dsystem15= dd.Discrete_Doucet_system(theta = theta_approx15 )
dsystem4 = dd.Discrete_Doucet_system(theta =theta_approx4 )

# %%
dsystem40.theta,  dsystem12.theta, dsystem.theta
# Out:
# (array([ -1.23481912,   0.2656946 ,   3.44532589, -13.88883684,   0.2       ]),
#  array([ -0.6987144 ,  -0.49409199, -25.09107122,   6.33720366,   0.2       ]),
#  array([  0. ,   0.5,  25. ,   6. ,   0.2]))

# %%
simul40 =  dd.Simulate(T = 40)
simul12 =  dd.Simulate(T = 12)
simul4 =  dd.Simulate(T = 4)
simul15 =  dd.Simulate(T = 15)
nxtest = 20000
nxobs = 1000

# %%
xobs40, pobs40= simul40.simulate(dsystem, Nx= nxobs,  seed = 1)
xdat40, pdat40= simul40.simulate(dsystem40, Nx= nxtest,  seed = 2)

xobs12, pobs12= simul12.simulate(dsystem, Nx= nxobs,  seed = 1)
xdat12, pdat12= simul40.simulate(dsystem12, Nx= nxtest,  seed = 2)


xobs4, pobs4= simul4.simulate(dsystem, Nx= nxobs,  seed = 1)
xdat4, pdat4= simul4.simulate(dsystem4, Nx= nxtest,  seed = 2)


xobs15, pobs15= simul15.simulate(dsystem, Nx= nxobs,  seed = 2)
xdat15, pdat15= simul15.simulate(dsystem15, Nx= nxtest,  seed = 2)

# %%
plt.hist(xdat40,bins=50, normed=True, label = "xdat approx" )
plt.hist(xobs40,bins=50, normed=True, label = "xdat truth")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
plt.hist(xdat12,bins=50, normed=True, label = "xdat approx" )
plt.hist(xobs12,bins=50, normed=True, label = "xdat truth")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
nxobs_s = 1000
nxtest_s = 20000
xobs12s, pobs12s= simul12.simulate(dsystem, Nx= nxobs_s,  seed = 1)
xdat12s, pdat12s= simul40.simulate(dsystem12, Nx= nxtest_s,  seed = 2)

px12 = dsystem.compare(xobs12s, xdat12s)
px_try = nxtest * dsystem.compare(xdat12s, xobs12s) 
xdat_try_ordered = np.sort(xdat12s)
px_try_ordered = px_try[np.argsort(xdat12s)]

plt.plot(xdat_try_ordered, px_try_ordered)

# %%
plt.hist(xdat4,bins=50, normed=True, label = "xdat approx" )
plt.hist(xobs4,bins=50, normed=True, label = "xdat truth")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
plt.hist(xdat15,bins=50, normed=True, label = "xdat approx" )
plt.hist(xobs15,bins=50, normed=True, label = "xdat truth")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()
