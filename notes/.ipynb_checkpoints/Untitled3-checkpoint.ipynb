# %%
import numpy as np
import scipy as sp
from matplotlib import pyplot as plt
# %matplotlib inline
import sys
sys.path.append("../source") 
import Discrete_Doucet_system as dd
reload(dd)
# Out:
# <module 'Discrete_Doucet_system' from '../source/Discrete_Doucet_system.pyc'>

# %%
theta_approx40 = np.array([  1.02644295,   0.20038815,  12.98241266, -11.06179256,   0.2       ])
theta_approx12 = np.array([ -4.24012446,  -0.39731519, -27.46642095,   6.88204985,   0.2       ])
#theta_approx12 = np.array([ 0.01680314,  0.92671352,  3.81007087,  0.21282745 , 0.2       ])
dsystem = dd.Discrete_Doucet_system()
dsystem40 = dd.Discrete_Doucet_system(theta =theta_approx40 )
dsystem12= dd.Discrete_Doucet_system(theta = theta_approx12 )

# %%
simul40 =  dd.Simulate(T = 40)
simul12 =  dd.Simulate(T = 12)
nxtest = 20000

# %%
xobs40, pobs40= simul40.simulate(dsystem, Nx= nxtest,  seed = 2)
xdat40, pdat40= simul40.simulate(dsystem40, Nx= nxtest,  seed = 2)

xobs12, pobs12= simul12.simulate(dsystem, Nx= nxtest,  seed = 2)
xdat12, pdat12= simul40.simulate(dsystem12, Nx= nxtest,  seed = 2)

# %%
plt.hist(xdat40,bins=50, normed=True, label = "xdat approx" )
plt.hist(xobs40,bins=50, normed=True, label = "xdat truth")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
plt.hist(xdat12,bins=50, normed=True, label = "xdat approx" )
plt.hist(xobs12,bins=50, normed=True, label = "xdat truth")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()
